# %% [markdown]
# # Re-estimation of a transition matrix

# %%
import numpy as np
import scipy
import pyemma
import matplotlib.pyplot as plt
from importlib import reload
import markovtests 
markovtests = reload(markovtests)

# %% [markdown]
# ## Generate discrete trajectory from transition matrix

# %%
import random
import numpy as np

size = 100000

T = np.matrix([[ 0.97, 0.03, 0],[0.015 , 0.97, 0.015],[ 0, 0.03, 0.97]])
#print(T)

def state0(i,num):
    if num>T[0,0]:
        return i+1
    return i

def state1(i,num):
    if num<T[1,0]:
        return i-1
    elif T[1,0]<num<(T[1,2]+T[1,0]):
        return i+1
    return i

def state2(i,num):
    if num>T[2,2]:
        return i-1
    return i

def decider(i, num):
    new_i = i
    if i==0:
        new_i = state0(i,num)
    if i==1:
        new_i = state1(i,num)
    if i==2:
        new_i = state2(i,num)

    return new_i


i=0 # initial condition
k=0

dtraj=[]
while k<size:
    num = random.uniform(0, 1)
    i = decider(i, num)
    dtraj.append(i)
    k=k+1

# %% [markdown]
# ## Generate continuous trajectory from discrete trajectory

# %%
# parameters

mu_0 = [0,0]
mu_1 = [5,5]
mu_2 = [-10,-10]

sigma_0 = [[1,0],[0,1]]
sigma_1 = [[1,0],[0,1]]
sigma_2 = [[1,0],[0,1]]

mus = [mu_0, mu_1, mu_2]
sigmas = [sigma_0, sigma_1, sigma_2]

# generates a continuous trajectory drawn from bivariate gaussians
def generate_traj(dtraj, mus, sigmas):
    traj = []
    for i in range(len(dtraj)):
        if dtraj[i] == 0:
            traj.append(np.random.multivariate_normal(mus[0], sigmas[0], size=1)[0])
        elif dtraj[i] == 1:
            traj.append(np.random.multivariate_normal(mus[1], sigmas[1], size=1)[0])
        elif dtraj[i] == 2:
            traj.append(np.random.multivariate_normal(mus[2], sigmas[2], size=1)[0])
        else:
            print("something went wrong")
            exit()
    return np.array(traj)

traj = generate_traj(dtraj, mus, sigmas)

#print(traj)

# %% [markdown]
# ## Rotate trajectory into 5 dimensions and add noise

# %%
def randommatrix():
    v=np.array([np.random.random() for n in range(5)])
    w=np.array([np.random.random() for n in range(5)])
    #generating two random 5d vectors
    vn=v/np.sqrt(sum(v**2))
    wn=(w-np.dot(w,vn)*vn)/np.sqrt(sum((w-np.dot(w,vn)*vn)**2))
    #orthonormalization with Gram-Schmidt
    
    return np.array([vn,wn])

def fived(x,y, random_matrix,noize):
    noize_matrix=[[np.random.random() - 0.5 for n in range(5)],[np.random.normal() for n in range(5)],[np.random.poisson() for n in range(5)]]
    out=np.matmul(np.array([x,y]), random_matrix) + np.array(noize_matrix[noize])
    return out

# %%
traj_5dim = []

for i in range(len(traj)):
    traj_5dim.append(fived(traj[i,0],traj[i,1], randommatrix(), 0))

traj_5dim = np.array(traj_5dim)

# %% [markdown]
# ## Analyse generated trajectory with pyEMMA

# %%
#specify data
data = traj_5dim

tica = pyemma.coordinates.tica(data, lag=10, dim=2)
tica_concatenated = np.concatenate(tica.get_output())

cls_tica = pyemma.coordinates.cluster_kmeans(tica, k=3, max_iter=50, stride=10)
its_tica = pyemma.msm.its(cls_tica.dtrajs, lags=[1, 2, 5, 10, 20], nits=3, errors='bayes')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='initialize kmeans++ centers', layout=Layout(flex='2'), ma…
# HBox(children=(FloatProgress(value=0.0, description='kmeans iterations', layout=Layout(flex='2'), max=50.0, st…
# HBox(children=(FloatProgress(value=0.0, description='estimating BayesianMSM', layout=Layout(flex='2'), max=5.0…
# 21-02-20 12:10:12 pyemma.msm.estimators.implied_timescales.ImpliedTimescales[416] WARNING  Changed user setting nits to the number of available timescales nits=2

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 6))
pyemma.plots.plot_feature_histograms(tica_concatenated, ax=axes[0])
axes[0].set_title('TICA')
pyemma.plots.plot_density(*tica_concatenated.T, ax=axes[1], cbar=False, alpha=0.1)

axes[1].scatter(*cls_tica.clustercenters.T, s=15, c='C1')
axes[1].set_xlabel('IC 1')
axes[1].set_ylabel('IC 2')
pyemma.plots.plot_implied_timescales(its_tica, ax=axes[2], units='ps')
axes[2].set_ylim(1, 2000)
axes[2].set_ylim(1, 2000)
fig.tight_layout()

# %%
#specify data
data = traj_5dim

tica = pyemma.coordinates.tica(data, lag=1, dim = 2)
#tica = pyemma.coordinates.tica(data, lag=1, dim=2)
tica_concatenated = np.concatenate(tica.get_output())

cls_tica = pyemma.coordinates.cluster_kmeans(tica, k=3, max_iter=50, stride=10)
its_tica = pyemma.msm.its(cls_tica.dtrajs, lags=[1, 2, 5, 10, 20], nits=2, errors='bayes')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='initialize kmeans++ centers', layout=Layout(flex='2'), ma…
# HBox(children=(FloatProgress(value=0.0, description='kmeans iterations', layout=Layout(flex='2'), max=50.0, st…
# HBox(children=(FloatProgress(value=0.0, description='estimating BayesianMSM', layout=Layout(flex='2'), max=5.0…

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 6))
pyemma.plots.plot_feature_histograms(tica_concatenated, ax=axes[0])
axes[0].set_title('TICA')
pyemma.plots.plot_density(*tica_concatenated.T, ax=axes[1], cbar=False, alpha=0.1)

axes[1].scatter(*cls_tica.clustercenters.T, s=15, c='C1')
axes[1].set_xlabel('IC 1')
axes[1].set_ylabel('IC 2')
pyemma.plots.plot_implied_timescales(its_tica, ax=axes[2], units='ps')
axes[2].set_ylim(1, 2000)
axes[2].set_ylim(1, 2000)
fig.tight_layout()

# %% [markdown]
# # The evolution of transition matrix until lag=1 and lag=10

# %%
# generate msm
bayesian_msm = pyemma.msm.bayesian_markov_model(cls_tica.dtrajs, lag=1, dt_traj='1 ps')
fake_msm = pyemma.msm.estimate_markov_model(dtraj, lag=1, dt_traj = '1 ps')

markovtests.plot_cktest((fake_msm.cktest(3), bayesian_msm.cktest(3)))
# Out:
# HBox(children=(FloatProgress(value=0.0, description='pyemma.msm.estimators.bayesian_msm.BayesianMSM[432]: comp…
# HBox(children=(FloatProgress(value=0.0, description='pyemma.msm.estimators.bayesian_msm.BayesianMSM[432]: Samp…
# HBox(children=(FloatProgress(value=0.0, description='estimating MaximumLikelihoodMSM', layout=Layout(flex='2')…
# HBox(children=(FloatProgress(value=0.0, description='estimating BayesianMSM', layout=Layout(flex='2'), max=9.0…
# plotting 0
# plotting 1
# (<Figure size 648x648 with 9 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002164FD6B278>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002164F925B38>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002164F910A58>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002164F91A978>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002164FFC8438>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002164FF33A90>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002164E6BD048>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002164E0B2BA8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002164E066F98>]],
#        dtype=object))

# %%
# generate msm
bayesian_msm = pyemma.msm.bayesian_markov_model(cls_tica.dtrajs, lag=10, dt_traj='1 ps')
fake_msm = pyemma.msm.estimate_markov_model(dtraj, lag=1, dt_traj = '1 ps')
# plot ck test
markovtests.plot_cktest((fake_msm.cktest(3),bayesian_msm.cktest(3)), units='ps')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='pyemma.msm.estimators.bayesian_msm.BayesianMSM[454]: comp…
# HBox(children=(FloatProgress(value=0.0, description='pyemma.msm.estimators.bayesian_msm.BayesianMSM[454]: Samp…
# HBox(children=(FloatProgress(value=0.0, description='estimating MaximumLikelihoodMSM', layout=Layout(flex='2')…
# HBox(children=(FloatProgress(value=0.0, description='estimating BayesianMSM', layout=Layout(flex='2'), max=9.0…
# plotting 0
# plotting 1
# (<Figure size 648x648 with 9 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002164187CCF8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000216416CDC50>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000216410EA048>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002164E11D438>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000021650481128>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002164171B0F0>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002164B837160>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000021645ABDEF0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000021651127D30>]],
#        dtype=object))

# %%
#from importlib import reload

# %%
#import markovtests

# %%
#markovtests = reload(markovtests)

# %%
#import matplotlib as mpl

# %%
#from pyemma.plots.markovtests import _add_ck_subplot as add_ck

# %%
#fig, ax = ax_fake
